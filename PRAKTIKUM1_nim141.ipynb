# %% [markdown]
# ## Nama : Nasywa Nurul Hidayah

# %% [markdown]
# ## NIM : 2023-32-141

# %% [markdown]
# ## Kelas : B32

# %%
pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#IMPORT LIBRARY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Membuat Bar Chart

# %%
MataKuliah = ['Dasar Pemrograman','Basis Data',
              'Machine Learning', 'Pemrograman Objek',
              'Pemrograman Web']
Jumlah_mahasiswa = [125,90,128,99,77]

plt.figure(figsize=(22,7))
plt.barh(MataKuliah, Jumlah_mahasiswa, color='blue')
plt.title('Jumlah Mahasiswa pada matakuliah di semester 3',size=14)
plt.xlabel('Jumlah Mahasiswa', size=12)
plt.xticks(size=12)
plt.yticks(size=12)
plt.show()

# %% [markdown]
# ## Line Chart

# %%
#Line Chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Nilai = [80,90,65,75,79,82]
ax.plot(Nilai)
plt.show()

# %%
#PIE CHART
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal') #memastikan pie chart berbentuk lingkaran

# Data produk jumlah terjual
stock =['Cheese','Bread','Ice Cream','Noodles', 'Egg']
sold = [10, 50, 45, 15, 37, 113]

# Membuat pie chart
ax.pie(sold, labels=stock, autopct='%1.2f%%')

# Mengatur aspek rasio agar tidak ada peringatan
plt.gca().set_aspect('equal', adjustable='box')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 13
#      10 sold = [10, 50, 45, 15, 37, 113]
#      12 # Membuat pie chart
# ---> 13 ax.pie(sold, labels=stock, autopct='%1.2f%%')
#      15 # Mengatur aspek rasio agar tidak ada peringatan
#      16 plt.gca().set_aspect('equal', adjustable='box')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:3351, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3349     explode = [0] * len(x)
#    3350 if len(x) != len(labels):
# -> 3351     raise ValueError(f"'labels' must be of length 'x', not {len(labels)}")
#    3352 if len(x) != len(explode):
#    3353     raise ValueError(f"'explode' must be of length 'x', not {len(explode)}")
#
# ValueError: 'labels' must be of length 'x', not 5

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')  # Ensure the pie chart is circular

# Data produk jumlah terjual
stock = ['Cheese', 'Bread', 'Ice Cream', 'Noodles', 'Egg']
sold = [10, 50, 45, 15, 37]  # Removed the extra value to match the length of 'stock'

# Membuat pie chart
ax.pie(sold, labels=stock, autopct='%1.2f%%')

plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
# Data untuk tiga kategori
akomodasi = [2000, 1100, 4180, 5800, 6420, 980]
kamar = [1503, 10732, 3555, 5206, 2187, 4731, 522]
kasur = [9257, 16415, 6045, 7832, 2885, 8080, 786]
 
# Membuat figure dan axis
fig, ax = plt.subplots(figsize=(8,6))  # Ukuran lebih jelas
 
# Membuat boxplot dengan berbagai pengaturan
box = ax.boxplot([akomodasi, kamar, kasur],
                 vert=False,  # Membuat boxplot horizontal
                 showmeans=True,  # Menampilkan nilai mean
                 meanline=True,  # Menampilkan mean sebagai garis
                 tick_labels=['Akomodasi', 'Kamar', 'Kasur'],  # Perbaikan: 'labels' → 'tick_labels'
                 patch_artist=True,  # Memberikan warna pada boxplot
                 medianprops={'linewidth': 2, 'color': 'blue'},  # Warna garis median
                 meanprops={'linewidth': 2, 'color': 'red'})  # Warna garis mean
 
# Menambahkan warna untuk setiap box
colors = ['lightblue', 'lightgreen', 'lightcoral']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
 
# Menyesuaikan aspek agar tidak terjadi peringatan
ax.set_aspect('auto')
 
# Menampilkan plot
plt.show()

# %% [markdown]
# ## Scatter PLOT

# %%
# Data nilai tugas, UTS, dan UAS
tugas = [58, 80, 65, 79, 82]
uts = [78, 80, 85, 59, 92]
uas = [62, 79, 87, 77, 84]
 
# Membuat figure dan axis
fig, ax = plt.subplots()
 
# Scatter plot hubungan tugas dengan UTS
ax.scatter(tugas, uts, color='red', label='Tugas vs UTS')
# Scatter plot hubungan tugas dengan UAS
ax.scatter(tugas, uas, color='blue', label='Tugas vs UAS')
 
# Menambahkan label sumbu dan judul
tempX = 'Tugas'
tempY = 'Nilai'
ax.set_xlabel(tempX)
ax.set_ylabel(tempY)
ax.set_title('Scatter Plot')
 
# Menampilkan legenda
ax.legend()
 
# Menampilkan plot
plt.show()

# %%
#IMPORT LIBRARY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Baca Dataset

# %%
df = pd.read_csv('botak.csv')

# %%
df
# Out:
#       umur jenis_kelamin       pekerjaan      provinsi          gaji  \
# 0     42.0     Laki-laki             PNS        Padang  7.864005e+06
# 1     33.0     Laki-laki  Pegawai swasta  Palangkaraya  6.492662e+06
# 2     59.0     Laki-laki       Freelance        Serang  8.086303e+06
# 3     38.0     Laki-laki  Pegawai swasta     Gorontalo  1.147321e+07
# 4     33.0     Perempuan       Freelance  Tanjungselor  1.475942e+07
# ...    ...           ...             ...           ...           ...
# 7986  31.0     Laki-laki  Pegawai swasta        Padang  2.911963e+07
# 7987  40.0     Perempuan  Pegawai swasta   Banjarmasin  8.955173e+06
# 7988  43.0     Perempuan             PNS       Mataram  4.022652e+06
# 7989  29.0     Laki-laki  Pegawai swasta        Serang  5.801753e+06
# 7990  55.0     Laki-laki  Pegawai swasta        Padang  8.518947e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 0              0           0.0  61.928685  152.174164         Deadbuoy
# 1              0           0.0  49.374507  152.822969         Moonsilk
# 2              1           0.0  59.072807  159.911047          Merpati
# 3              0           1.0  68.338014  162.558997         Moonsilk
# 4              0           0.0  53.769996  154.579510          Pantone
# ...          ...           ...        ...         ...              ...
# 7986           0           0.0  83.272785  176.020857          Merpati
# 7987           0           0.0  61.634474  161.780773         Deadbuoy
# 7988           0           0.0  50.525031  152.461656  Shoulder & Head
# 7989           0           0.0  47.175270  152.749709              NaN
# 7990           0           1.0  61.938728  163.998842          Merpati
#
#       is_merokok pendidikan  botak_prob
# 0              1         S1    0.487655
# 1              1        SMA    0.297270
# 2              1         S1    0.467848
# 3              0         S1    0.616418
# 4              1         S2    0.115439
# ...          ...        ...         ...
# 7986           0        SMA    0.241525
# 7987           0         S1    0.140971
# 7988           1         S1    0.364456
# 7989           1        SMA    0.248910
# 7990           1        SMA    0.838493
#
# [7991 rows x 13 columns]

# %%
#manggil 5 data dari atas

df.head()
# Out:
#    umur jenis_kelamin       pekerjaan      provinsi          gaji  is_menikah  \
# 0  42.0     Laki-laki             PNS        Padang  7.864005e+06           0
# 1  33.0     Laki-laki  Pegawai swasta  Palangkaraya  6.492662e+06           0
# 2  59.0     Laki-laki       Freelance        Serang  8.086303e+06           1
# 3  38.0     Laki-laki  Pegawai swasta     Gorontalo  1.147321e+07           0
# 4  33.0     Perempuan       Freelance  Tanjungselor  1.475942e+07           0
#
#    is_keturunan      berat      tinggi     sampo  is_merokok pendidikan  \
# 0           0.0  61.928685  152.174164  Deadbuoy           1         S1
# 1           0.0  49.374507  152.822969  Moonsilk           1        SMA
# 2           0.0  59.072807  159.911047   Merpati           1         S1
# 3           1.0  68.338014  162.558997  Moonsilk           0         S1
# 4           0.0  53.769996  154.579510   Pantone           1         S2
#
#    botak_prob
# 0    0.487655
# 1    0.297270
# 2    0.467848
# 3    0.616418
# 4    0.115439

# %%
#manggil 5 data dari bawah

df.tail()
# Out:
#       umur jenis_kelamin       pekerjaan     provinsi          gaji  \
# 7986  31.0     Laki-laki  Pegawai swasta       Padang  2.911963e+07
# 7987  40.0     Perempuan  Pegawai swasta  Banjarmasin  8.955173e+06
# 7988  43.0     Perempuan             PNS      Mataram  4.022652e+06
# 7989  29.0     Laki-laki  Pegawai swasta       Serang  5.801753e+06
# 7990  55.0     Laki-laki  Pegawai swasta       Padang  8.518947e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 7986           0           0.0  83.272785  176.020857          Merpati
# 7987           0           0.0  61.634474  161.780773         Deadbuoy
# 7988           0           0.0  50.525031  152.461656  Shoulder & Head
# 7989           0           0.0  47.175270  152.749709              NaN
# 7990           0           1.0  61.938728  163.998842          Merpati
#
#       is_merokok pendidikan  botak_prob
# 7986           0        SMA    0.241525
# 7987           0         S1    0.140971
# 7988           1         S1    0.364456
# 7989           1        SMA    0.248910
# 7990           1        SMA    0.838493

# %%
#diambil data secara acak

df.sample(5)
# Out:
#       umur jenis_kelamin       pekerjaan        provinsi          gaji  \
# 6404  43.0     Laki-laki  Pegawai swasta    Palangkaraya  9.874900e+06
# 1275  37.0     Laki-laki             PNS  Tanjung Pinang  6.919560e+06
# 95    33.0     Laki-laki  Pegawai swasta          Padang  8.604214e+06
# 6420  29.0     Perempuan  Pegawai swasta    Palangkaraya  9.380595e+06
# 2557  43.0     Laki-laki             PNS        Surabaya  9.469819e+06
#
#       is_menikah  is_keturunan      berat      tinggi     sampo  is_merokok  \
# 6404           0           1.0  50.942224  150.629537   Pantone           0
# 1275           0           0.0  56.559971  157.660311       NaN           1
# 95             0           0.0  54.503439  156.249019  Deadbuoy           0
# 6420           0           1.0        NaN  151.701243   Pantone           0
# 2557           0           1.0  62.296118  155.893628  Moonsilk           1
#
#      pendidikan  botak_prob
# 6404        SMP    0.639504
# 1275        SMA    0.417447
# 95           S1    0.150449
# 6420         S1    0.368693
# 2557        SMA    0.768971

# %%
#memberi tahu jenis datanya(baca dataset)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   umur           7991 non-null   float64
#  1   jenis_kelamin  7982 non-null   object
#  2   pekerjaan      7924 non-null   object
#  3   provinsi       7991 non-null   object
#  4   gaji           7968 non-null   float64
#  5   is_menikah     7991 non-null   int64
#  6   is_keturunan   7976 non-null   float64
#  7   berat          7952 non-null   float64
#  8   tinggi         7991 non-null   float64
#  9   sampo          7934 non-null   object
#  10  is_merokok     7991 non-null   int64
#  11  pendidikan     7991 non-null   object
#  12  botak_prob     7991 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 811.7+ KB

# %%
# guna nya untuk nampilin detail suatu kolom

df['umur'].describe()
# Out:
# count    7991.000000
# mean       39.604805
# std        10.014420
# min         3.000000
# 25%        33.000000
# 50%        40.000000
# 75%        46.000000
# max        78.000000
# Name: umur, dtype: float64

# %%
#cth lainnya:
df['jenis_kelamin'].describe()
# Out:
# count          7991
# unique            2
# top       Laki-laki
# freq           5351
# Name: jenis_kelamin, dtype: object

# %% [markdown]
# ## MISSING VALUE

# %%
# untuk memberi tahu missing value
#misaL: 
#di kolom: "umur": ga ada yg missing(perfect),
#sedangkan didlm kolom: "jenis_kelamin" ada sembilan(9) yg hilang


df.isna().sum()
# Out:
# umur             0
# jenis_kelamin    0
# pekerjaan        0
# provinsi         0
# gaji             0
# is_menikah       0
# is_keturunan     0
# berat            0
# tinggi           0
# sampo            0
# is_merokok       0
# pendidikan       0
# botak_prob       0
# dtype: int64

# %%
# Mengisi nilai missing value dengan ketentuan:
# Modus untuk data kategorik dan mean untuk data numerik
 
from statistics import mode
 
# Menghitung modus untuk data kategorik
jenis_kelamin_mode = mode(df['jenis_kelamin'].dropna())
pekerjaan_mode = mode(df['pekerjaan'].dropna())
is_keturunan_mode = mode(df['is_keturunan'].dropna())
sampo_mode = mode(df['sampo'].dropna())
 
# Menghitung mean untuk data numerik
berat_mean = df['berat'].mean()
gaji_mean = df['gaji'].mean()
 
# Daftar kolom yang memiliki nilai missing
kolom_missing = ['jenis_kelamin', 'pekerjaan',
                 'is_keturunan', 'berat', 'sampo', 'gaji']
 
# Daftar nilai yang akan digunakan untuk mengisi missing values
inputan = [jenis_kelamin_mode, pekerjaan_mode,
           is_keturunan_mode, berat_mean, sampo_mode, gaji_mean]
 
# Mengisi nilai missing dengan metode yang benar
for kolom, nilai in zip(kolom_missing, inputan):
    df[kolom] = df[kolom].fillna(nilai)

# %%
#coba cek lagi

df.isna().sum()
# Out:
# umur             0
# jenis_kelamin    0
# pekerjaan        0
# provinsi         0
# gaji             0
# is_menikah       0
# is_keturunan     0
# berat            0
# tinggi           0
# sampo            0
# is_merokok       0
# pendidikan       0
# botak_prob       0
# dtype: int64

# %% [markdown]
# ## Atasi duplikasi

# %%
#mengatasi duplcate data
df.duplicated().sum()
# Out:
# 101

# %%
df_hapus_duplikat = df.drop_duplicates()
df_hapus_duplikat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7890 entries, 0 to 7989
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   umur           7890 non-null   float64
#  1   jenis_kelamin  7890 non-null   object
#  2   pekerjaan      7890 non-null   object
#  3   provinsi       7890 non-null   object
#  4   gaji           7890 non-null   float64
#  5   is_menikah     7890 non-null   int64
#  6   is_keturunan   7890 non-null   float64
#  7   berat          7890 non-null   float64
#  8   tinggi         7890 non-null   float64
#  9   sampo          7890 non-null   object
#  10  is_merokok     7890 non-null   int64
#  11  pendidikan     7890 non-null   object
#  12  botak_prob     7890 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 863.0+ KB
